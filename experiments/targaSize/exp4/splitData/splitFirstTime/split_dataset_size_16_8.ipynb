# %%
import cv2
import os
import PIL
import skimage
from skimage import data
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
from random import randint
import tensorflow as tf
from scipy import ndimage, misc
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_data(data_directory):
    directories = [d for d in os.listdir(data_directory) 
                   if os.path.isdir(os.path.join(data_directory, d))]
    labels = []
    images = []
    image_name=[]
    for d in directories:
        label_directory = os.path.join(data_directory, d)
        file_names = [os.path.join(label_directory, f) 
                      for f in os.listdir(label_directory) if f.endswith(".jpg")]
        for f in file_names:
            images.append(skimage.data.imread(f))
            labels.append(str(d))
            image_name.append(str(f))
    return images, labels,image_name

# %%
ROOT_PATH = '/home/tang/targa/exp4/size16*8/'

train_data_directory = os.path.join(ROOT_PATH, "train")
test_data_directory = os.path.join(ROOT_PATH, "test")
validation_data_directory = os.path.join(ROOT_PATH,'validation')
total_data_directory = os.path.join(ROOT_PATH, "total_data")

# %%
os.listdir(total_data_directory+'/0')
# Out:
# ['0_possionnoise_lamda_550.jpg',
#  '0_gaussian_sigma_0.171.jpg',
#  '0_gaussian_sigma_0.212.jpg',
#  '0_specklenoise_sigma_230.jpg',
#  '0_peppernoise_amount_0.276.jpg',
#  '0_possionnoise_lamda_871.jpg',
#  '0_gaussian_sigma_0.019.jpg',
#  '0_perspective_0_0_1_13_6_12_7_0.jpg',
#  '0_possionnoise_lamda_159.jpg',
#  '0_saltnoise_amount_0.058.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_16_th_-7_tw_-1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_6_th_-4_tw_0.jpg',
#  '0_translation__-6_0.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_28_th_-7_tw_3.jpg',
#  '0_salt&pepper_amount_0.368ratio of s&p_0.59.jpg',
#  '0_perspective_0_2_1_12_7_15_7_2.jpg',
#  '0_salt&pepper_amount_0.207ratio of s&p_0.31.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-17_th_-4_tw_-2.jpg',
#  '0_perspective_1_0_1_13_7_13_6_2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-18_th_6_tw_0.jpg',
#  '0h__222.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-25_th_5_tw_0.jpg',
#  '0_salt&pepper_amount_0.361ratio of s&p_0.51.jpg',
#  '0_specklenoise_sigma_104.jpg',
#  '0_salt&pepper_amount_0.282ratio of s&p_0.53.jpg',
#  '0_salt&pepper_amount_0.497ratio of s&p_0.45.jpg',
#  '0_salt&pepper_amount_0.194ratio of s&p_0.5.jpg',
#  '0_specklenoise_sigma_291.jpg',
#  '0_perspective_1_0_1_14_6_12_7_1.jpg',
#  '0_gaussian_sigma_0.181.jpg',
#  '0_specklenoise_sigma_157.jpg',
#  '0_gamma__3.18.jpg',
#  '0_percentile_bluring_percentile_39_size_2.jpg',
#  '0h__236.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_21_th_-6_tw_0.jpg',
#  '0_possionnoise_lamda_761.jpg',
#  '0_possionnoise_lamda_13.jpg',
#  '0_perspective_0_3_0_13_7_15_6_2.jpg',
#  '0_specklenoise_sigma_79.jpg',
#  '0_possionnoise_lamda_971.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_-23_th_-7_tw_-3.jpg',
#  '0_percentile_bluring_percentile_71_size_2.jpg',
#  '0_perspective_0_2_1_12_6_13_7_3.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-27_th_-4_tw_0.jpg',
#  '0_saltnoise_amount_0.481.jpg',
#  '0_perspective_1_2_0_14_7_13_7_3.jpg',
#  '0_specklenoise_sigma_282.jpg',
#  '0_salt&pepper_amount_0.323ratio of s&p_0.43.jpg',
#  '0_salt&pepper_amount_0.453ratio of s&p_0.68.jpg',
#  '0_possionnoise_lamda_642.jpg',
#  '0_perspective_1_0_0_14_7_15_7_0.jpg',
#  '0_gaussian_sigma_0.073.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_-29_th_-6_tw_2.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_19_th_-5_tw_0.jpg',
#  '0_peppernoise_amount_0.022.jpg',
#  '0_peppernoise_amount_0.197.jpg',
#  '0_perspective_1_1_0_14_6_15_6_2.jpg',
#  '0_specklenoise_sigma_81.jpg',
#  '0_salt&pepper_amount_0.219ratio of s&p_0.42.jpg',
#  '0_salt&pepper_amount_0.202ratio of s&p_0.66.jpg',
#  '0_perspective_1_1_1_12_7_14_6_1.jpg',
#  '0_perspective_1_2_0_14_7_12_6_0.jpg',
#  '0_perspective_1_1_0_12_7_14_6_2.jpg',
#  '0_peppernoise_amount_0.141.jpg',
#  '0_salt&pepper_amount_0.3ratio of s&p_0.33.jpg',
#  '0_salt&pepper_amount_0.433ratio of s&p_0.35.jpg',
#  '0_salt&pepper_amount_0.087ratio of s&p_0.47.jpg',
#  '0_perspective_0_0_1_12_6_13_6_1.jpg',
#  '0_minimum_bluring_factor_2.0.jpg',
#  '0v__210.jpg',
#  '0_gaussian_bluring_sigma2.86.jpg',
#  '0_rotate__5.jpg',
#  '0_salt&pepper_amount_0.354ratio of s&p_0.7.jpg',
#  '0_percentile_bluring_percentile_22_size_2.jpg',
#  '0_gaussian_sigma_0.124.jpg',
#  '0_gaussian_sigma_0.206.jpg',
#  '0_perspective_1_0_1_15_7_13_7_3.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_14_th_-6_tw_-2.jpg',
#  '0_perspective_1_2_1_14_6_13_7_0.jpg',
#  '0_possionnoise_lamda_157.jpg',
#  '0_perspective_0_2_1_13_6_12_7_3.jpg',
#  '0_perspective_1_3_0_12_7_14_7_2.jpg',
#  '0_perspective_0_0_0_13_6_12_6_1.jpg',
#  '0_sheared__0075.jpg',
#  '0_salt&pepper_amount_0.478ratio of s&p_0.39.jpg',
#  '0s_0_.jpg',
#  '0_gaussian_sigma_0.252.jpg',
#  '0_gaussian_sigma_0.021.jpg',
#  '0_possionnoise_lamda_778.jpg',
#  '0_salt&pepper_amount_0.305ratio of s&p_0.67.jpg',
#  '0_gaussian_sigma_0.27.jpg',
#  '0_sheared__0028.jpg',
#  '0_possionnoise_lamda_995.jpg',
#  '0_salt&pepper_amount_0.083ratio of s&p_0.38.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-6_th_6_tw_-3.jpg',
#  '0_gaussian_sigma_0.229.jpg',
#  '0_percentile_bluring_percentile_2_size_2.jpg',
#  '0_gamma__3.76.jpg',
#  '0_sheared__0017.jpg',
#  '0_specklenoise_sigma_84.jpg',
#  '0_salt&pepper_amount_0.213ratio of s&p_0.59.jpg',
#  '0h__233.jpg',
#  '0_percentile_bluring_percentile_67_size_2.jpg',
#  '0_possionnoise_lamda_110.jpg',
#  '0_gaussian_bluring_sigma0.57.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_0_th_5_tw_-2.jpg',
#  '0_salt&pepper_amount_0.456ratio of s&p_0.33.jpg',
#  '0_peppernoise_amount_0.462.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-21_th_-7_tw_-3.jpg',
#  '0_translation__-4_1.jpg',
#  '0_gaussian_bluring_sigma4.75.jpg',
#  '0_salt&pepper_amount_0.209ratio of s&p_0.42.jpg',
#  '0_salt&pepper_amount_0.449ratio of s&p_0.4.jpg',
#  '0_perspective_0_1_0_12_7_13_6_3.jpg',
#  '0_salt&pepper_amount_0.34ratio of s&p_0.47.jpg',
#  '0_possionnoise_lamda_445.jpg',
#  '0_gaussian_bluring_sigma3.19.jpg',
#  '0_possionnoise_lamda_119.jpg',
#  '0_salt&pepper_amount_0.18ratio of s&p_0.52.jpg',
#  '0_possionnoise_lamda_783.jpg',
#  '0_saltnoise_amount_0.292.jpg',
#  '0_gaussian_sigma_0.017.jpg',
#  '0_salt&pepper_amount_0.457ratio of s&p_0.43.jpg',
#  '0_perspective_0_2_0_12_6_13_6_1.jpg',
#  '0_specklenoise_sigma_74.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_16_th_3_tw_3.jpg',
#  '0_peppernoise_amount_0.455.jpg',
#  '0_possionnoise_lamda_14.jpg',
#  '0_gaussian_sigma_0.115.jpg',
#  '0_percentile_bluring_percentile_29_size_2.jpg',
#  '0_saltnoise_amount_0.024.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_-1_r_19_th_-1_tw_2.jpg',
#  '0_gaussian_sigma_0.077.jpg',
#  '0_saltnoise_amount_0.18.jpg',
#  '0_bilateral_bluring_color14spatial_1.jpg',
#  '0_salt&pepper_amount_0.081ratio of s&p_0.5.jpg',
#  '0_bilateral_bluring_color9spatial_1.jpg',
#  '0_possionnoise_lamda_125.jpg',
#  '0_specklenoise_sigma_134.jpg',
#  '0_gaussian_sigma_0.151.jpg',
#  '0_salt&pepper_amount_0.447ratio of s&p_0.35.jpg',
#  '0_saltnoise_amount_0.215.jpg',
#  '0_possionnoise_lamda_557.jpg',
#  '0_possionnoise_lamda_438.jpg',
#  '0h__242.jpg',
#  '0_specklenoise_sigma_59.jpg',
#  '0_specklenoise_sigma_190.jpg',
#  '0_possionnoise_lamda_167.jpg',
#  '0_salt&pepper_amount_0.209ratio of s&p_0.37.jpg',
#  '0_gaussian_sigma_0.084.jpg',
#  '0_salt&pepper_amount_0.341ratio of s&p_0.51.jpg',
#  '0_salt&pepper_amount_0.407ratio of s&p_0.53.jpg',
#  '0_specklenoise_sigma_193.jpg',
#  '0_peppernoise_amount_0.379.jpg',
#  '0_gaussian_bluring_sigma8.6.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-2_th_-7_tw_2.jpg',
#  '0_percentile_bluring_percentile_11_size_2.jpg',
#  '0_bilateral_bluring_color7spatial_1.jpg',
#  '0_gaussian_sigma_0.056.jpg',
#  '0_gaussian_sigma_0.3.jpg',
#  '0_salt&pepper_amount_0.248ratio of s&p_0.34.jpg',
#  '0_peppernoise_amount_0.396.jpg',
#  '0_possionnoise_lamda_694.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_-11_th_0_tw_1.jpg',
#  '0_perspective_0_1_1_12_7_15_7_2.jpg',
#  '0_salt&pepper_amount_0.065ratio of s&p_0.61.jpg',
#  '0_gaussian_bluring_sigma3.77.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_10_th_3_tw_-3.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-20_th_-3_tw_0.jpg',
#  '0v__173.jpg',
#  '0_gaussian_bluring_sigma6.46.jpg',
#  '0_possionnoise_lamda_786.jpg',
#  '0_specklenoise_sigma_223.jpg',
#  '0_translation__-3_1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_7_th_-5_tw_-2.jpg',
#  '0_salt&pepper_amount_0.183ratio of s&p_0.65.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_29_th_6_tw_1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_17_th_-7_tw_0.jpg',
#  '0_peppernoise_amount_0.48.jpg',
#  '0_peppernoise_amount_0.282.jpg',
#  '0v__203.jpg',
#  '0_bilateral_bluring_color2spatial_1.jpg',
#  '0_gaussian_sigma_0.172.jpg',
#  '0_peppernoise_amount_0.465.jpg',
#  '0_perspective_0_2_0_12_6_13_7_3.jpg',
#  '0_possionnoise_lamda_613.jpg',
#  '0_perspective_0_0_1_12_7_14_7_3.jpg',
#  '0_gaussian_sigma_0.075.jpg',
#  '0_gaussian_sigma_0.248.jpg',
#  '0_perspective_1_2_0_13_7_15_6_1.jpg',
#  '0_perspective_1_3_1_14_6_13_6_1.jpg',
#  '0_sheared__0038.jpg',
#  '0_perspective_0_1_1_15_7_15_6_0.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_0_th_-5_tw_-1.jpg',
#  '0_gamma__5.09.jpg',
#  '0_gaussian_bluring_sigma6.8.jpg',
#  '0_bilateral_bluring_color10spatial_1.jpg',
#  '0_gaussian_sigma_0.043.jpg',
#  '0_sheared__00-50.jpg',
#  '0_sheared__00-96.jpg',
#  '0_median_bluring_1.jpg',
#  '0_specklenoise_sigma_204.jpg',
#  '0_salt&pepper_amount_0.203ratio of s&p_0.37.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-3_th_4_tw_3.jpg',
#  '0_saltnoise_amount_0.188.jpg',
#  '0_gaussian_bluring_sigma9.64.jpg',
#  '0_specklenoise_sigma_243.jpg',
#  '0_translation__-1_-2.jpg',
#  '0_possionnoise_lamda_18.jpg',
#  '0_possionnoise_lamda_599.jpg',
#  '0_possionnoise_lamda_207.jpg',
#  '0_random_bluring_h_2_w_2.jpg',
#  '0_gaussian_sigma_0.111.jpg',
#  '0_specklenoise_sigma_76.jpg',
#  '0_possionnoise_lamda_590.jpg',
#  '0_peppernoise_amount_0.042.jpg',
#  '0_specklenoise_sigma_14.jpg',
#  '0_gamma__7.73.jpg',
#  '0_gaussian_bluring_sigma8.38.jpg',
#  '0_saltnoise_amount_0.191.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_28_th_-6_tw_0.jpg',
#  '0_specklenoise_sigma_255.jpg',
#  '0_gaussian_bluring_sigma7.09.jpg',
#  '0_possionnoise_lamda_633.jpg',
#  '0_perspective_0_0_0_13_6_13_6_0.jpg',
#  '0_gaussian_sigma_0.274.jpg',
#  '0_salt&pepper_amount_0.07ratio of s&p_0.57.jpg',
#  '0_perspective_1_0_1_13_6_14_6_0.jpg',
#  '0_possionnoise_lamda_46.jpg',
#  '0_salt&pepper_amount_0.289ratio of s&p_0.39.jpg',
#  '0_salt&pepper_amount_0.293ratio of s&p_0.33.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-20_th_5_tw_-2.jpg',
#  '0_salt&pepper_amount_0.331ratio of s&p_0.46.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_-29_th_1_tw_2.jpg',
#  '0_gaussian_bluring_sigma7.42.jpg',
#  '0_salt&pepper_amount_0.473ratio of s&p_0.68.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_-28_th_7_tw_-2.jpg',
#  '0_specklenoise_sigma_55.jpg',
#  '0_perspective_0_2_1_15_7_14_7_0.jpg',
#  '0_perspective_1_1_0_14_7_12_7_2.jpg',
#  '0_gamma__5.55.jpg',
#  '0_gaussian_sigma_0.087.jpg',
#  '0_perspective_1_3_1_15_6_14_7_1.jpg',
#  '0_salt&pepper_amount_0.391ratio of s&p_0.67.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_23_th_-5_tw_-3.jpg',
#  '0_perspective_0_1_0_15_6_12_7_3.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_24_th_-7_tw_2.jpg',
#  '0_possionnoise_lamda_659.jpg',
#  '0v__238.jpg',
#  '0_minimum_bluring_factor_3.0.jpg',
#  '0_salt&pepper_amount_0.097ratio of s&p_0.57.jpg',
#  '0_specklenoise_sigma_166.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-12_th_-2_tw_1.jpg',
#  '0_gaussian_sigma_0.047.jpg',
#  '0_salt&pepper_amount_0.311ratio of s&p_0.36.jpg',
#  '0_perspective_0_2_1_13_6_12_6_0.jpg',
#  '0_gaussian_sigma_0.029.jpg',
#  '0_perspective_1_3_1_12_7_15_6_2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-26_th_7_tw_-3.jpg',
#  '0_perspective_0_1_1_15_6_15_6_0.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_-16_th_3_tw_0.jpg',
#  '0_peppernoise_amount_0.125.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_6_th_-1_tw_-3.jpg',
#  '0_specklenoise_sigma_257.jpg',
#  '0_specklenoise_sigma_191.jpg',
#  '0_saltnoise_amount_0.078.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-19_th_-3_tw_-3.jpg',
#  '0_gaussian_sigma_0.039.jpg',
#  '0_gaussian_sigma_0.139.jpg',
#  '0_perspective_0_3_1_13_7_14_7_2.jpg',
#  '0v__185.jpg',
#  '0_perspective_1_2_1_12_6_14_6_2.jpg',
#  '0_peppernoise_amount_0.307.jpg',
#  '0_gamma__3.5.jpg',
#  '0_salt&pepper_amount_0.261ratio of s&p_0.6.jpg',
#  '0_percentile_bluring_percentile_64_size_2.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_-1_r_-16_th_4_tw_-3.jpg',
#  '0_gaussian_sigma_0.137.jpg',
#  '0_sheared__0059.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_20_th_7_tw_-1.jpg',
#  '0_perspective_1_0_0_13_6_14_7_0.jpg',
#  '0_gamma__4.77.jpg',
#  '0_salt&pepper_amount_0.348ratio of s&p_0.38.jpg',
#  '0_gaussian_bluring_sigma7.3.jpg',
#  '0_perspective_1_2_0_12_6_12_7_3.jpg',
#  '0_peppernoise_amount_0.035.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_16_th_-4_tw_1.jpg',
#  '0_salt&pepper_amount_0.168ratio of s&p_0.58.jpg',
#  '0_gaussian_sigma_0.211.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-17_th_7_tw_-2.jpg',
#  '0_saltnoise_amount_0.142.jpg',
#  '0_perspective_0_0_1_13_7_15_6_2.jpg',
#  '0_saltnoise_amount_0.064.jpg',
#  '0_specklenoise_sigma_297.jpg',
#  '0_specklenoise_sigma_121.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-28_th_4_tw_-3.jpg',
#  '0_possionnoise_lamda_868.jpg',
#  '0_sheared__0064.jpg',
#  '0_salt&pepper_amount_0.393ratio of s&p_0.44.jpg',
#  '0_saltnoise_amount_0.267.jpg',
#  '0_rotate__10.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_17_th_0_tw_3.jpg',
#  '0_saltnoise_amount_0.493.jpg',
#  '0_bilateral_bluring_color5spatial_1.jpg',
#  '0_possionnoise_lamda_444.jpg',
#  '0_salt&pepper_amount_0.321ratio of s&p_0.47.jpg',
#  '0_gaussian_sigma_0.179.jpg',
#  '0_possionnoise_lamda_113.jpg',
#  '0_sheared__0083.jpg',
#  '0h__223.jpg',
#  '0_sheared__00-27.jpg',
#  '0_salt&pepper_amount_0.381ratio of s&p_0.51.jpg',
#  '0_specklenoise_sigma_117.jpg',
#  '0_gaussian_sigma_0.189.jpg',
#  '0_rotate__-15.jpg',
#  '0_salt&pepper_amount_0.45ratio of s&p_0.68.jpg',
#  '0_salt&pepper_amount_0.325ratio of s&p_0.38.jpg',
#  '0v__132.jpg',
#  '0_peppernoise_amount_0.166.jpg',
#  '0_possionnoise_lamda_913.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-2_th_-4_tw_-1.jpg',
#  '0_rotate__-2.jpg',
#  '0_perspective_1_2_1_15_6_12_7_0.jpg',
#  '0_specklenoise_sigma_43.jpg',
#  '0_gaussian_sigma_0.243.jpg',
#  '0v__244.jpg',
#  '0h__241.jpg',
#  '0_saltnoise_amount_0.018.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_19_th_2_tw_1.jpg',
#  '0_perspective_1_1_1_15_7_14_6_1.jpg',
#  '0_percentile_bluring_percentile_10_size_2.jpg',
#  '0_possionnoise_lamda_515.jpg',
#  '0_perspective_0_1_1_15_7_14_7_1.jpg',
#  '0_salt&pepper_amount_0.049ratio of s&p_0.6.jpg',
#  '0_bilateral_bluring_color3spatial_1.jpg',
#  '0_possionnoise_lamda_702.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_3_th_-4_tw_-1.jpg',
#  '0_rotate__20.jpg',
#  '0_possionnoise_lamda_268.jpg',
#  '0_specklenoise_sigma_171.jpg',
#  '0_saltnoise_amount_0.422.jpg',
#  '0_peppernoise_amount_0.21.jpg',
#  '0_perspective_1_0_0_15_7_13_6_0.jpg',
#  '0_possionnoise_lamda_603.jpg',
#  '0_specklenoise_sigma_36.jpg',
#  '0_rotate__-21.jpg',
#  '0_perspective_1_3_1_13_6_14_7_0.jpg',
#  '0_possionnoise_lamda_161.jpg',
#  '0_gaussian_sigma_0.143.jpg',
#  '0_gaussian_bluring_sigma2.69.jpg',
#  '0_possionnoise_lamda_876.jpg',
#  '0_specklenoise_sigma_167.jpg',
#  '0_saltnoise_amount_0.423.jpg',
#  '0_possionnoise_lamda_398.jpg',
#  '0_possionnoise_lamda_867.jpg',
#  '0_possionnoise_lamda_520.jpg',
#  '0_salt&pepper_amount_0.114ratio of s&p_0.46.jpg',
#  '0_percentile_bluring_percentile_48_size_2.jpg',
#  '0_bilateral_bluring_color13spatial_1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_-17_th_0_tw_0.jpg',
#  '0_specklenoise_sigma_290.jpg',
#  '0_gaussian_sigma_0.201.jpg',
#  '0_perspective_1_0_1_12_6_12_6_3.jpg',
#  '0_percentile_bluring_percentile_77_size_2.jpg',
#  '0_translation__0_3.jpg',
#  '0_rotate__-29.jpg',
#  '0_specklenoise_sigma_269.jpg',
#  '0_specklenoise_sigma_143.jpg',
#  '0_gamma__9.37.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-3_th_0_tw_-2.jpg',
#  '0_gaussian_sigma_0.095.jpg',
#  '0_salt&pepper_amount_0.016ratio of s&p_0.5.jpg',
#  '0_salt&pepper_amount_0.364ratio of s&p_0.36.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_-26_th_-2_tw_3.jpg',
#  '0_gaussian_bluring_sigma1.11.jpg',
#  '0_maximum_bluring_size1.0.jpg',
#  '0_peppernoise_amount_0.285.jpg',
#  '0_peppernoise_amount_0.365.jpg',
#  '0_salt&pepper_amount_0.24ratio of s&p_0.35.jpg',
#  '0_perspective_0_3_1_15_7_12_7_1.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-28_th_-4_tw_-2.jpg',
#  '0_saltnoise_amount_0.461.jpg',
#  '0_gaussian_bluring_sigma5.46.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-28_th_7_tw_0.jpg',
#  '0_possionnoise_lamda_276.jpg',
#  '0_gaussian_sigma_0.117.jpg',
#  '0_specklenoise_sigma_129.jpg',
#  '0_specklenoise_sigma_28.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_-13_th_1_tw_-1.jpg',
#  '0_perspective_0_3_0_14_6_13_6_1.jpg',
#  '0_gaussian_sigma_0.263.jpg',
#  '0_peppernoise_amount_0.195.jpg',
#  '0_perspective_0_0_0_13_7_12_6_2.jpg',
#  '0v__232.jpg',
#  '0_saltnoise_amount_0.171.jpg',
#  '0_specklenoise_sigma_194.jpg',
#  '0_possionnoise_lamda_453.jpg',
#  '0_perspective_0_2_1_14_7_13_6_3.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_8_th_2_tw_-3.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_-26_th_-7_tw_1.jpg',
#  '0_peppernoise_amount_0.215.jpg',
#  '0_rotate__-20.jpg',
#  '0_specklenoise_sigma_169.jpg',
#  '0_specklenoise_sigma_144.jpg',
#  '0_gamma__4.85.jpg',
#  '0_possionnoise_lamda_789.jpg',
#  '0v__146.jpg',
#  '0_salt&pepper_amount_0.051ratio of s&p_0.42.jpg',
#  '0_saltnoise_amount_0.26.jpg',
#  '0_bilateral_bluring_color15spatial_1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-2_th_7_tw_1.jpg',
#  '0_peppernoise_amount_0.137.jpg',
#  '0_rotate__16.jpg',
#  '0h__225.jpg',
#  '0_possionnoise_lamda_929.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_17_th_-6_tw_-3.jpg',
#  '0_specklenoise_sigma_153.jpg',
#  '0h__228.jpg',
#  '0_possionnoise_lamda_864.jpg',
#  '0_gamma__9.66.jpg',
#  '0_perspective_0_0_1_14_7_14_6_0.jpg',
#  '0_percentile_bluring_percentile_38_size_2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_5_th_0_tw_0.jpg',
#  '0_specklenoise_sigma_54.jpg',
#  '0_specklenoise_sigma_259.jpg',
#  '0_perspective_1_2_0_13_7_13_7_1.jpg',
#  '0_gaussian_bluring_sigma8.32.jpg',
#  '0_specklenoise_sigma_101.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_15_th_1_tw_0.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_8_th_4_tw_0.jpg',
#  '0_salt&pepper_amount_0.481ratio of s&p_0.68.jpg',
#  '0_gaussian_sigma_0.295.jpg',
#  '0_gaussian_sigma_0.02.jpg',
#  '0_specklenoise_sigma_125.jpg',
#  '0_possionnoise_lamda_952.jpg',
#  '0_possionnoise_lamda_330.jpg',
#  '0_perspective_1_0_0_13_6_13_7_3.jpg',
#  '0h__238.jpg',
#  '0_percentile_bluring_percentile_58_size_2.jpg',
#  '0_peppernoise_amount_0.262.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_22_th_-2_tw_3.jpg',
#  '0_specklenoise_sigma_233.jpg',
#  '0_saltnoise_amount_0.205.jpg',
#  '0_perspective_1_0_0_14_6_15_7_2.jpg',
#  '0v__191.jpg',
#  '0_gaussian_sigma_0.132.jpg',
#  '0_salt&pepper_amount_0.376ratio of s&p_0.37.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-4_th_-5_tw_2.jpg',
#  '0_specklenoise_sigma_221.jpg',
#  '0_gaussian_sigma_0.018.jpg',
#  '0h__220.jpg',
#  '0_gamma__5.46.jpg',
#  '0_gaussian_sigma_0.255.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_24_th_2_tw_-3.jpg',
#  '0_perspective_1_0_0_15_7_15_7_1.jpg',
#  '0_gaussian_sigma_0.237.jpg',
#  '0_perspective_0_1_1_13_6_14_6_2.jpg',
#  '0_rotate__-11.jpg',
#  '0h__221.jpg',
#  '0_specklenoise_sigma_292.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-9_th_6_tw_1.jpg',
#  '0_perspective_1_1_0_14_7_13_7_3.jpg',
#  '0_specklenoise_sigma_215.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-13_th_0_tw_-1.jpg',
#  '0_possionnoise_lamda_188.jpg',
#  '0_saltnoise_amount_0.306.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-25_th_6_tw_-2.jpg',
#  '0v__252.jpg',
#  '0_specklenoise_sigma_184.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_14_th_-6_tw_-1.jpg',
#  '0v__177.jpg',
#  '0_possionnoise_lamda_567.jpg',
#  '0_sheared__0054.jpg',
#  '0_percentile_bluring_percentile_81_size_2.jpg',
#  '0_gaussian_sigma_0.198.jpg',
#  '0_specklenoise_sigma_148.jpg',
#  '0_perspective_1_0_0_15_7_12_6_2.jpg',
#  '0_perspective_0_2_1_13_7_12_6_1.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_3_th_-4_tw_3.jpg',
#  '0_possionnoise_lamda_301.jpg',
#  '0_gaussian_sigma_0.05.jpg',
#  '0_gaussian_sigma_0.157.jpg',
#  '0v__186.jpg',
#  '0_perspective_1_2_0_12_7_13_6_2.jpg',
#  '0_salt&pepper_amount_0.449ratio of s&p_0.65.jpg',
#  '0_salt&pepper_amount_0.401ratio of s&p_0.52.jpg',
#  '0_bilateral_bluring_color8spatial_1.jpg',
#  '0_possionnoise_lamda_747.jpg',
#  '0_salt&pepper_amount_0.462ratio of s&p_0.63.jpg',
#  '0_possionnoise_lamda_927.jpg',
#  '0_peppernoise_amount_0.097.jpg',
#  '0h__244.jpg',
#  '0_saltnoise_amount_0.448.jpg',
#  '0_gaussian_sigma_0.168.jpg',
#  '0_gaussian_sigma_0.286.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_0_th_-7_tw_-2.jpg',
#  '0_specklenoise_sigma_253.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_-1_r_11_th_6_tw_1.jpg',
#  '0v__170.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_-5_th_0_tw_3.jpg',
#  '0_salt&pepper_amount_0.247ratio of s&p_0.66.jpg',
#  '0_average_bluring_h_2_w_2.jpg',
#  '0_gaussian_sigma_0.246.jpg',
#  '0_possionnoise_lamda_760.jpg',
#  '0_saltnoise_amount_0.357.jpg',
#  '0_gaussian_sigma_0.205.jpg',
#  '0_salt&pepper_amount_0.265ratio of s&p_0.63.jpg',
#  '0_gaussian_bluring_sigma3.87.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_10_th_-6_tw_0.jpg',
#  '0_possionnoise_lamda_255.jpg',
#  '0_possionnoise_lamda_426.jpg',
#  '0_perspective_1_2_1_14_6_12_6_3.jpg',
#  '0_perspective_0_1_0_12_7_14_6_0.jpg',
#  '0_perspective_0_0_0_12_7_13_7_1.jpg',
#  '0_perspective_1_1_1_15_6_12_6_0.jpg',
#  '0_gaussian_sigma_0.118.jpg',
#  '0_sheared__0087.jpg',
#  '0_salt&pepper_amount_0.304ratio of s&p_0.69.jpg',
#  '0_perspective_1_0_1_15_7_12_7_3.jpg',
#  '0_salt&pepper_amount_0.133ratio of s&p_0.63.jpg',
#  '0v__131.jpg',
#  '0_gaussian_bluring_sigma8.14.jpg',
#  '0_gaussian_sigma_0.197.jpg',
#  '0_salt&pepper_amount_0.365ratio of s&p_0.55.jpg',
#  '0_perspective_0_1_1_15_7_13_7_3.jpg',
#  '0_perspective_1_2_0_13_7_15_7_2.jpg',
#  '0_peppernoise_amount_0.445.jpg',
#  '0_possionnoise_lamda_572.jpg',
#  '0_specklenoise_sigma_126.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_-1_r_29_th_-3_tw_-1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-19_th_-6_tw_-2.jpg',
#  '0_perspective_1_1_0_12_6_12_6_1.jpg',
#  '0_perspective_0_3_0_14_7_15_6_0.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-3_th_2_tw_-2.jpg',
#  '0_perspective_0_1_0_12_7_12_6_2.jpg',
#  '0_sheared__0050.jpg',
#  '0_perspective_0_3_1_12_6_13_7_2.jpg',
#  '0_possionnoise_lamda_55.jpg',
#  '0_salt&pepper_amount_0.484ratio of s&p_0.48.jpg',
#  '0v__243.jpg',
#  '0_perspective_1_0_1_12_6_15_7_3.jpg',
#  '0_percentile_bluring_percentile_91_size_2.jpg',
#  '0_rotate__28.jpg',
#  '0_percentile_bluring_percentile_54_size_2.jpg',
#  '0_gaussian_sigma_0.297.jpg',
#  '0h__240.jpg',
#  '0_gaussian_sigma_0.106.jpg',
#  '0_saltnoise_amount_0.249.jpg',
#  '0_percentile_bluring_percentile_78_size_2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-18_th_0_tw_0.jpg',
#  '0_specklenoise_sigma_270.jpg',
#  '0_sheared__0027.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_-1_r_-5_th_-6_tw_1.jpg',
#  '0_gaussian_sigma_0.266.jpg',
#  '0_specklenoise_sigma_85.jpg',
#  '0_rotate__-16.jpg',
#  '0_gaussian_sigma_0.26.jpg',
#  '0_gaussian_sigma_0.023.jpg',
#  '0_possionnoise_lamda_324.jpg',
#  '0_saltnoise_amount_0.083.jpg',
#  '0_gaussian_bluring_sigma2.37.jpg',
#  '0_possionnoise_lamda_800.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_-3_th_-4_tw_2.jpg',
#  '0_specklenoise_sigma_106.jpg',
#  '0_gaussian_sigma_0.083.jpg',
#  '0_perspective_0_2_0_14_6_12_7_3.jpg',
#  '0_specklenoise_sigma_245.jpg',
#  '0_gaussian_bluring_sigma7.61.jpg',
#  '0_peppernoise_amount_0.381.jpg',
#  '0_gaussian_sigma_0.244.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_4_th_-7_tw_0.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-19_th_-2_tw_0.jpg',
#  '0v__193.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_26_th_4_tw_-3.jpg',
#  '0_sheared__00-71.jpg',
#  '0_possionnoise_lamda_575.jpg',
#  '0_possionnoise_lamda_35.jpg',
#  '0_gaussian_bluring_sigma0.18.jpg',
#  '0_specklenoise_sigma_262.jpg',
#  '0_rotate__8.jpg',
#  '0_salt&pepper_amount_0.339ratio of s&p_0.6.jpg',
#  '0_gaussian_bluring_sigma7.31.jpg',
#  '0_salt&pepper_amount_0.086ratio of s&p_0.59.jpg',
#  '0_salt&pepper_amount_0.448ratio of s&p_0.31.jpg',
#  '0_affined_shear_00-47_sx_1_sy_-1_r_-6_th_-6_tw_2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_6_th_2_tw_-2.jpg',
#  '0_salt&pepper_amount_0.261ratio of s&p_0.47.jpg',
#  '0_saltnoise_amount_0.112.jpg',
#  '0_saltnoise_amount_0.469.jpg',
#  '0_perspective_1_1_0_12_7_12_7_2.jpg',
#  '0_specklenoise_sigma_294.jpg',
#  '0_perspective_0_1_1_15_6_14_7_3.jpg',
#  '0_gaussian_sigma_0.185.jpg',
#  '0_peppernoise_amount_0.02.jpg',
#  '0_specklenoise_sigma_199.jpg',
#  '0_perspective_1_1_1_13_7_13_6_0.jpg',
#  '0_possionnoise_lamda_173.jpg',
#  '0_possionnoise_lamda_41.jpg',
#  '0_possionnoise_lamda_946.jpg',
#  '0_possionnoise_lamda_914.jpg',
#  '0_perspective_1_0_0_14_7_13_6_1.jpg',
#  '0_gaussian_bluring_sigma8.8.jpg',
#  '0_perspective_1_0_0_14_6_12_7_0.jpg',
#  '0_specklenoise_sigma_147.jpg',
#  '0_possionnoise_lamda_730.jpg',
#  '0_specklenoise_sigma_275.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_5_th_1_tw_2.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_-15_th_0_tw_0.jpg',
#  '0_specklenoise_sigma_30.jpg',
#  '0_gaussian_sigma_0.186.jpg',
#  '0_peppernoise_amount_0.181.jpg',
#  '0_perspective_0_3_0_14_7_15_7_0.jpg',
#  '0_perspective_1_3_0_13_7_15_7_0.jpg',
#  '0_gaussian_bluring_sigma9.01.jpg',
#  '0_possionnoise_lamda_592.jpg',
#  '0_rotate__27.jpg',
#  '0_perspective_1_3_1_15_6_13_7_1.jpg',
#  '0_gaussian_sigma_0.272.jpg',
#  '0_possionnoise_lamda_336.jpg',
#  '0_perspective_1_0_1_14_6_14_7_3.jpg',
#  '0_rotate__-17.jpg',
#  '0_gaussian_sigma_0.283.jpg',
#  '0_percentile_bluring_percentile_84_size_2.jpg',
#  '0_specklenoise_sigma_29.jpg',
#  '0_gamma__1.51.jpg',
#  '0h__246.jpg',
#  '0_saltnoise_amount_0.467.jpg',
#  '0_gamma__6.92.jpg',
#  '0_salt&pepper_amount_0.149ratio of s&p_0.49.jpg',
#  '0_perspective_1_0_0_12_6_14_7_3.jpg',
#  '0_perspective_0_0_0_13_6_15_7_2.jpg',
#  '0_gaussian_sigma_0.142.jpg',
#  '0_salt&pepper_amount_0.186ratio of s&p_0.42.jpg',
#  '0_gaussian_sigma_0.012.jpg',
#  '0_gamma__9.19.jpg',
#  '0_bilateral_bluring_color1spatial_1.jpg',
#  '0_gaussian_sigma_0.027.jpg',
#  '0_rotate__-22.jpg',
#  '0_specklenoise_sigma_206.jpg',
#  '0_specklenoise_sigma_241.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-6_th_-1_tw_2.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-18_th_0_tw_0.jpg',
#  '0_specklenoise_sigma_89.jpg',
#  '0_salt&pepper_amount_0.35ratio of s&p_0.49.jpg',
#  '0_salt&pepper_amount_0.165ratio of s&p_0.36.jpg',
#  '0_possionnoise_lamda_556.jpg',
#  '0_possionnoise_lamda_763.jpg',
#  '0_possionnoise_lamda_658.jpg',
#  '0_sheared__0099.jpg',
#  '0_perspective_0_1_1_13_6_15_6_0.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_0_th_1_tw_0.jpg',
#  '0v__199.jpg',
#  '0_specklenoise_sigma_264.jpg',
#  '0_saltnoise_amount_0.387.jpg',
#  '0_specklenoise_sigma_225.jpg',
#  '0_rotate__2.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-15_th_0_tw_3.jpg',
#  '0_perspective_0_1_1_15_7_15_6_3.jpg',
#  '0_gamma__2.57.jpg',
#  '0_perspective_1_3_0_12_6_14_6_1.jpg',
#  '0_perspective_0_3_0_12_7_15_7_3.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_14_th_-5_tw_3.jpg',
#  '0_affined_shear_00-47_sx_0_sy_1_r_-5_th_0_tw_1.jpg',
#  '0_possionnoise_lamda_357.jpg',
#  '0_salt&pepper_amount_0.275ratio of s&p_0.52.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-15_th_1_tw_0.jpg',
#  '0_salt&pepper_amount_0.274ratio of s&p_0.42.jpg',
#  '0_gaussian_sigma_0.271.jpg',
#  '0_percentile_bluring_percentile_52_size_2.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_15_th_4_tw_1.jpg',
#  '0_gaussian_sigma_0.154.jpg',
#  '0_perspective_0_0_1_15_6_12_7_3.jpg',
#  '0_gaussian_sigma_0.28.jpg',
#  '0_gaussian_sigma_0.048.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_5_th_7_tw_0.jpg',
#  '0_gamma__6.02.jpg',
#  '0v__215.jpg',
#  '0_possionnoise_lamda_450.jpg',
#  '0_perspective_0_3_0_14_7_13_7_3.jpg',
#  '0_gamma__0.19.jpg',
#  '0_perspective_1_3_0_15_7_12_7_3.jpg',
#  '0_salt&pepper_amount_0.372ratio of s&p_0.54.jpg',
#  '0_specklenoise_sigma_66.jpg',
#  '0_gamma__3.45.jpg',
#  '0_bilateral_bluring_color4spatial_1.jpg',
#  '0_gaussian_bluring_sigma0.56.jpg',
#  '0_peppernoise_amount_0.478.jpg',
#  '0_gaussian_sigma_0.04.jpg',
#  '0_salt&pepper_amount_0.229ratio of s&p_0.57.jpg',
#  '0_perspective_0_2_0_15_6_15_6_1.jpg',
#  '0_perspective_1_1_1_14_7_15_7_3.jpg',
#  '0_perspective_0_2_1_12_7_13_6_1.jpg',
#  '0_possionnoise_lamda_618.jpg',
#  '0_possionnoise_lamda_559.jpg',
#  '0_possionnoise_lamda_226.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_20_th_0_tw_-3.jpg',
#  '0_sheared__00-90.jpg',
#  '0_specklenoise_sigma_195.jpg',
#  '0_gaussian_bluring_sigma0.01.jpg',
#  '0_affined_shear_00-47_sx_1_sy_1_r_-24_th_0_tw_-2.jpg',
#  '0_salt&pepper_amount_0.073ratio of s&p_0.62.jpg',
#  '0_gaussian_bluring_sigma9.7.jpg',
#  '0_specklenoise_sigma_196.jpg',
#  '0_peppernoise_amount_0.264.jpg',
#  '0_gaussian_bluring_sigma9.55.jpg',
#  '0_affined_shear_00-47_sx_1_sy_0_r_-20_th_-6_tw_0.jpg',
#  '0_affined_shear_00-47_sx_0_sy_-1_r_-17_th_-3_tw_0.jpg',
#  '0_gaussian_sigma_0.127.jpg',
#  '0_perspective_1_3_0_13_6_13_7_0.jpg',
#  '0_sheared__00-59.jpg',
#  '0_bilateral_bluring_color12spatial_1.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_1_r_-24_th_-2_tw_-3.jpg',
#  '0_gamma__5.16.jpg',
#  '0_bilateral_bluring_color0spatial_1.jpg',
#  '0h__234.jpg',
#  '0_gamma__3.8.jpg',
#  '0_bilateral_bluring_color11spatial_1.jpg',
#  '0_affined_shear_00-47_sx_0_sy_0_r_-21_th_7_tw_-2.jpg',
#  '0_affined_shear_00-47_sx_-1_sy_0_r_-15_th_0_tw_-1.jpg']

# %%
Images,Labels,Image_names = load_data(total_data_directory)

# %%
os.path.basename(Image_names[0])
# Out:
# 'J_saltnoise_amount_0.428.jpg'

# %%
Image_names[7]
# Out:
# '/home/tang/targa/exp4/size16*8/total_data/J/J_perspective_0_2_0_14_7_14_7_3.jpg'

# %%
plt.imshow(Images[0])

# %%
Labels[0]
# Out:
# 'J'

# %%
len(Labels)
# Out:
# 23017

# %%
#########define percentage of dataset
total_number = len(Labels)
train_number = int(total_number*0.8)
test_number = int(total_number*0.1)
validation_number = total_number-train_number-test_number

# %%
print('- Training-set:\t\t{}'.format(train_number))
print('- Test-set:\t\t{}'.format(test_number))
print('- Validation-set:\t{}'.format(validation_number))
# Out:
# - Training-set:		18413
# - Test-set:		2301
# - Validation-set:	2303

# %%
from random import sample

# %%
totalset_index = []
trainset_index = []
testset_index=[]
validationset_index=[]

# %%
#########generate total images index
for i in range(0,len(Labels)):
    totalset_index.append(str(i))

# %%
trainset_index = sample(totalset_index,train_number)

# %%
print('- Total-set index length:\t{}'.format(len(totalset_index)))
print('- Training-set index length:\t\t{}'.format(len(trainset_index)))
print('- Testing-set index length:\t\t{}'.format(len(testset_index)))
print('- Validation-set index length:\t{}'.format(len(validationset_index)))
# Out:
# - Total-set index length:	23017
# - Training-set index length:		18413
# - Testing-set index length:		0
# - Validation-set index length:	0

# %%
for i in trainset_index:
    filename = train_data_directory+'/'+Labels[int(i)]+'/'+os.path.basename(Image_names[int(i)])
    plt.imsave(filename,Images[int(i)])
    #print(filename)
    totalset_index.remove(i)

# %%
print('- Total-set index length:\t{}'.format(len(totalset_index)))
print('- Training-set index length:\t\t{}'.format(len(trainset_index)))
print('- Testing-set index length:\t\t{}'.format(len(testset_index)))
print('- Validation-set index length:\t{}'.format(len(validationset_index)))
# Out:
# - Total-set index length:	4604
# - Training-set index length:		18413
# - Testing-set index length:		0
# - Validation-set index length:	0

# %%
testset_index= sample(totalset_index,test_number)

# %%
for i in testset_index:
    filename = test_data_directory+'/'+Labels[int(i)]+'/'+os.path.basename(Image_names[int(i)])
    plt.imsave(filename,Images[int(i)])
    #print(filename)
    totalset_index.remove(i)

# %%
print('- Total-set index length:\t{}'.format(len(totalset_index)))
print('- Training-set index length:\t\t{}'.format(len(trainset_index)))
print('- Testing-set index length:\t\t{}'.format(len(testset_index)))
print('- Validation-set index length:\t{}'.format(len(validationset_index)))
# Out:
# - Total-set index length:	2303
# - Training-set index length:		18413
# - Testing-set index length:		2301
# - Validation-set index length:	0

# %%
validationset_index= sample(totalset_index,validation_number)

# %%
for i in validationset_index:
    filename = validation_data_directory+'/'+Labels[int(i)]+'/'+os.path.basename(Image_names[int(i)])
    plt.imsave(filename,Images[int(i)])
    #print(filename)
    totalset_index.remove(i)

# %%
print('- Total-set index length:\t{}'.format(len(totalset_index)))
print('- Training-set index length:\t\t{}'.format(len(trainset_index)))
print('- Testing-set index length:\t\t{}'.format(len(testset_index)))
print('- Validation-set index length:\t{}'.format(len(validationset_index)))
# Out:
# - Total-set index length:	0
# - Training-set index length:		18413
# - Testing-set index length:		2301
# - Validation-set index length:	2303
